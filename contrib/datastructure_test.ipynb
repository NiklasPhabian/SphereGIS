# %%
import sys
sys.path.insert(0, '../') 
import sphereGIS 
import datastructure
import geopandas
import matplotlib.pyplot as plt

# %%
polygons = geopandas.read_file('../data/santa_barbara.gpkg')
polygons = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))#[4:5]

# %%
polygons = datastructure.SphereGeoDataFrame(polygons)

# %%
fig, ax = plt.subplots(dpi=200)
ax.grid(True)

polygons[polygons.name == 'Tanzania']['sphere_geom'].iloc[0].nodes.as_point_df().plot(ax=ax)

# %%
fig, ax = plt.subplots(dpi=200)
ax.grid(True)

polygons['sphere_geom'].nodes.as_point_df().plot(ax=ax)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-fa1333e9c34a> in <module>()
#       2 ax.grid(True)
#       3
# ----> 4 polygons['sphere_geom'].nodes.as_point_df().plot(ax=ax)
#
# /home/griessbaum/.local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'nodes'

# %%
polygons['sphere_geom']
# Out:
# 0      <datastructure.SphericalPolygon object at 0x7f...
# 1      <datastructure.SphericalPolygon object at 0x7f...
# 2      <datastructure.SphericalPolygon object at 0x7f...
# 3      <datastructure.SphericalPolygon object at 0x7f...
# 4      <datastructure.SphericalPolygon object at 0x7f...
#                              ...
# 172    <datastructure.SphericalPolygon object at 0x7f...
# 173    <datastructure.SphericalPolygon object at 0x7f...
# 174    <datastructure.SphericalPolygon object at 0x7f...
# 175    <datastructure.SphericalPolygon object at 0x7f...
# 176    <datastructure.SphericalPolygon object at 0x7f...
# Name: sphere_geom, Length: 177, dtype: object
