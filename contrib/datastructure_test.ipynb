# %%
import sys
sys.path.insert(0, '../') 
import sphereGIS 
import datastructure
import geopandas
import matplotlib.pyplot as plt

# %%
polygons = geopandas.read_file('../data/santa_barbara.gpkg')
polygons = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))#[4:5]
polygons = geopandas.read_file('../data/caribbean.gpkg')[21:23]

# %%
polygons = datastructure.SphereGeoDataFrame(polygons)

# %%
fig, ax = plt.subplots(dpi=200)
ax.grid(True)


polygons.set_geometry('convex_hull').plot(ax=ax, edgecolor='black', linewidth=1)
polygons.plot(ax=ax, color='green', edgecolor='black', linewidth=1)
